# %%
import pandas as pd
import sqlalchemy as sql

# %% [markdown]
# ### NOTE: You will need to replicate the OONI db
#
# Please see [our instructions for replicating the OONI DB on Amazon EC2](https://gist.github.com/elsehow/7e26f4949cb8fca3bf80b5de5be7f106).
#
# Once you've done that, you can run this code on your EC2 instance

# %%
sql_engine = sql.create_engine('postgresql:///metadb')
df = pd.read_sql_query("SELECT * FROM autoclaved LIMIT 10", sql_engine)

df
# Out:
#    autoclaved_no                                           filename  \
# 0         202780  2018-08-24/20180823T000714Z-AR-AS10318-web_con...
# 1         202781  2018-08-24/20180823T000725Z-DE-AS6830-web_conn...
# 2         202782  2018-08-24/20180823T000806Z-DO-AS12066-web_con...
# 3         202783  2018-08-24/20180823T001208Z-IN-AS18196-web_con...
# 4         202784  2018-08-24/20180823T001309Z-MY-AS9534-web_conn...
# 5         202785  2018-08-24/20180823T001334Z-US-AS10796-web_con...
# 6         202786  2018-08-24/20180823T001842Z-IE-AS6830-web_conn...
# 7         202787  2018-08-24/20180823T002026Z-US-AS209-web_conne...
# 8         202788  2018-08-24/20180823T002630Z-US-AS0-web_connect...
# 9         187864             2018-06-30/web_connectivity.02.tar.lz4
#
#   bucket_date  code_ver  file_size  file_crc32  \
# 0  2018-08-24         5   42657144   160700205
# 1  2018-08-24         5   40868385  1564278531
# 2  2018-08-24         5   41256806   -22887888
# 3  2018-08-24         5   29617552 -1739827379
# 4  2018-08-24         5   26074854   542208005
# 5  2018-08-24         5   26208998 -1370232088
# 6  2018-08-24         5   26194290  1530179307
# 7  2018-08-24         5   30033691 -1443400824
# 8  2018-08-24         5   41878833 -1531251646
# 9  2018-06-30         5    7209651 -1701907233
#
#                                            file_sha1
# 0  [b'\xa4', b'\xb4', b'\x03', b'\x8d', b'C', b'E...
# 1  [b'\xd1', b'&', b'}', b'\xe3', b'`', b'\r', b'...
# 2  [b'\x8a', b'\xa4', b'\xa4', b'\xd7', b'<', b'\...
# 3  [b'\xd2', b'\xcf', b'\x90', b'\x0f', b'I', b'\...
# 4  [b'\x13', b'7', b'\x84', b'\xab', b'[', b'\xe7...
# 5  [b'V', b'\xb7', b'\xe0', b'e', b't', b'k', b'4...
# 6  [b"'", b'\xb1', b'G', b'3', b'\\', b'\xcd', b'...
# 7  [b'E', b'\xd9', b'-', b'\x89', b'\xf7', b'\xaa...
# 8  [b'o', b'\xcf', b')', b'\xf4', b'\xc6', b'\xb1...
# 9  [b'\xab', b'a', b'\xea', b'z', b'\xdd', b'\xba...
